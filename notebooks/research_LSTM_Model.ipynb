# %% [markdown]
# # LSTM Models

# %% [markdown]
# - **Objective**: quick research for the best latest pre-trained NLP model (PTM) for our project tasks.
# - **Source_1**: Qiu et al., 'Pre-trained Models for Natural Language Processing: A Survey,' 2020.
# - **Source_2**: Widyassari et al., 'Review of automatic text summarization techniques & methods,' 2020.
# - **Source_3**: Liu & Lapata, 'Text Summarization with Pretrained Encoders,' 2019

# %% [markdown]
# >When fine-tuning for a specific task, unlike ELMo
# whose parameters are usually fixed, parameters in
# BERT are jointly fine-tuned with additional taskspecific
# parameters.

# %% [markdown]
# ## note

# %% [markdown]
# - Gap Sentence Generation (GSG) for text summarization
# - Summarization: BERTSUM
# - Audio-Text PTMs: SpeechBERT
# - 'Extractive' or 'abstractive' summarizer?
# - 'Single' or 'multiple' documents
# - Feed Forward Neural Network (FFNN)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## quates

# %% [markdown]
# >Text summarization is a formidable challenge in the field of
# Natural Language Processing (NLP) (Rane and Govilkar, 2019;
# Shabbir Moiyadi et al., 2016) because it requires precise text analysis
# such as semantic analysis and lexical analysis to produce a
# good summary. A good summary, in addition, must contain important
# information and must be concise but also must consider
# aspects such as non-redundancy, relevance, coverage, coherence,
# and readability (Verma et al., 2019). Where to get all these aspects
# in a summary is a great challenge.

# %% [markdown]
# > Extractive summarization only chooses the most important words, sentences,
# and paragraphs to produce a summary. Extractive summarization
# has a weakness in terms of coherence between sentences in the
# summary. If compared to abstractive summarization, extractive is
# relatively easier than abstractive which is very complex because
# it requires extensive natural language processing (Gambhir and
# Gupta, 2017). Although extractive summaries are relatively easier
# than very complex abstract summaries, there are still many things
# that challenge researchers to do. For example, in determining the
# preprocessing stages that correspond to the dataset, choosing the
# right features, and how to maximize the features to get a better
# summary, determine the right approach and how to collaborate
# with one approach to another to improve summarizing performance
# better.

# %% [markdown]
# ## conclusion
